# %% [markdown]
# <a href="https://colab.research.google.com/github/kvssri/online-tihiitg/blob/main/Learning_Based_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import zipfile
import os

uploaded = files.upload()

zip_file = list(uploaded.keys())[0]
print("ZIP file:", zip_file)

extract_path = "/content/dataset"

with zipfile.ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("ZIP extracted successfully!")
# Out:
#      <input type="file" id="files-2641edde-6c43-4c2a-8e38-1675c9dd88ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2641edde-6c43-4c2a-8e38-1675c9dd88ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

for root, dirs, files_list in os.walk(extract_path):
    for file in files_list:
        print(os.path.join(root, file))
# Out:
# /content/dataset/Underwater-Image-Data-set-main/training_log 6.csv
# /content/dataset/Underwater-Image-Data-set-main/epoch_0115.7z
# /content/dataset/Underwater-Image-Data-set-main/epoch_0110.7z
# /content/dataset/Underwater-Image-Data-set-main/training_log 4.csv
# /content/dataset/Underwater-Image-Data-set-main/training_log 7.csv
# /content/dataset/Underwater-Image-Data-set-main/epoch_100.7z
# /content/dataset/Underwater-Image-Data-set-main/epoch_00100.7z
# /content/dataset/Underwater-Image-Data-set-main/training_log 3.csv
# /content/dataset/Underwater-Image-Data-set-main/epoch_0100.7z
# /content/dataset/Underwater-Image-Data-set-main/training_log 2.csv
# /content/dataset/Underwater-Image-Data-set-main/training_log 1.csv
# /content/dataset/Underwater-Image-Data-set-main/training_log 5.csv
# /content/dataset/Underwater-Image-Data-set-main/epoch_0135.7z
# /content/dataset/Underwater-Image-Data-set-main/epoch_0096.7z
# /content/dataset/Underwater-Image-Data-set-main/epoch_0120.7z
# ...

# %%
import os

csv_files = []

for root, dirs, files_list in os.walk("/content/dataset"):
    for file in files_list:
        if file.lower().endswith(".csv"):
            csv_files.append(os.path.join(root, file))

print("CSV files found:", len(csv_files))

for f in csv_files:
    print(f)
# Out:
# CSV files found: 8
# /content/dataset/Underwater-Image-Data-set-main/training_log 6.csv
# /content/dataset/Underwater-Image-Data-set-main/training_log 4.csv
# /content/dataset/Underwater-Image-Data-set-main/training_log 7.csv
# /content/dataset/Underwater-Image-Data-set-main/training_log 3.csv
# /content/dataset/Underwater-Image-Data-set-main/training_log 2.csv
# /content/dataset/Underwater-Image-Data-set-main/training_log 1.csv
# /content/dataset/Underwater-Image-Data-set-main/training_log 5.csv
# /content/dataset/Underwater-Image-Data-set-main/training_log 8.csv

# %%
import pandas as pd

for f in csv_files:
    temp = pd.read_csv(f)

    print("\n==============================")
    print("File:", os.path.basename(f))
    print("Shape:", temp.shape)
    print("Columns:", temp.columns.tolist())
    print("==============================")
    display(temp.head())
# Out:
# ...
# File: training_log 6.csv
# Shape: (1521, 5)
# Columns: ['epoch', 'step', 'gen_total', 'disc_loss', 'time_s']
# ...
#    epoch  step  gen_total  disc_loss     time_s
# 0     62     1   5.130928   0.749042  29.679657
# 1     62     2   5.337514   0.698042  34.161528
# 2     62     3   6.094767   0.698099  38.682715
# 3     62     4   5.333790   0.685004  43.190114
# 4     62     5  13.008395   0.712128  47.711985
# ...
# File: training_log 4.csv
# Shape: (3900, 5)
# Columns: ['epoch', 'step', 'gen_total', 'disc_loss', 'time_s']
# ...
#    epoch  step  gen_total  disc_loss     time_s
# 0      1     1  41.739376   0.868087  41.657429
# 1      1     2  38.098122   1.321275  48.058171
# 2      1     3  39.290417   1.176079  53.112906
# 3      1     4  39.941330   1.238547  57.937477
# 4      1     5  34.496300   0.709154  62.465671
# ...
# File: training_log 7.csv
# Shape: (3900, 5)
# Columns: ['epoch', 'step', 'gen_total', 'disc_loss', 'time_s']
# ...
#    epoch  step  gen_total  disc_loss     time_s
# ...

# %%
all_columns = set()

for f in csv_files:
    temp = pd.read_csv(f)
    all_columns.update(temp.columns)

print("All columns found:")
print(sorted(all_columns))

print("\nSoH present:", "SoH" in all_columns)
print("RUL present:", "RUL" in all_columns)
# Out:
# All columns found:
# ['disc_loss', 'epoch', 'gen_total', 'step', 'time_s']
#
# SoH present: False
# RUL present: False

# %%
csv_files = []

for root, dirs, files_list in os.walk(extract_path):
    for file in files_list:
        if file.lower().endswith(".csv"):
            csv_files.append(os.path.join(root, file))

print("CSV files found:", len(csv_files))

for f in csv_files:
    print(f)
# Out:
# CSV files found: 8
# /content/dataset/Underwater-Image-Data-set-main/training_log 6.csv
# /content/dataset/Underwater-Image-Data-set-main/training_log 4.csv
# /content/dataset/Underwater-Image-Data-set-main/training_log 7.csv
# /content/dataset/Underwater-Image-Data-set-main/training_log 3.csv
# /content/dataset/Underwater-Image-Data-set-main/training_log 2.csv
# /content/dataset/Underwater-Image-Data-set-main/training_log 1.csv
# /content/dataset/Underwater-Image-Data-set-main/training_log 5.csv
# /content/dataset/Underwater-Image-Data-set-main/training_log 8.csv

# %%
import pandas as pd

file_name = csv_files[0]

df = pd.read_csv(file_name)

print("Dataset loaded!")
print("Shape:", df.shape)
print("Columns:", df.columns.tolist())

display(df.head())
# Out:
# Dataset loaded!
# Shape: (1521, 5)
# Columns: ['epoch', 'step', 'gen_total', 'disc_loss', 'time_s']
#    epoch  step  gen_total  disc_loss     time_s
# 0     62     1   5.130928   0.749042  29.679657
# 1     62     2   5.337514   0.698042  34.161528
# 2     62     3   6.094767   0.698099  38.682715
# 3     62     4   5.333790   0.685004  43.190114
# 4     62     5  13.008395   0.712128  47.711985

# %%
for f in csv_files:
    temp = pd.read_csv(f)
    print("\nFile:", os.path.basename(f))
    print("Shape:", temp.shape)
    print("Columns:", temp.columns.tolist())
# Out:
# File: training_log 6.csv
# Shape: (1521, 5)
# Columns: ['epoch', 'step', 'gen_total', 'disc_loss', 'time_s']
#
# File: training_log 4.csv
# Shape: (3900, 5)
# Columns: ['epoch', 'step', 'gen_total', 'disc_loss', 'time_s']
#
# File: training_log 7.csv
# Shape: (3900, 5)
# Columns: ['epoch', 'step', 'gen_total', 'disc_loss', 'time_s']
#
# File: training_log 3.csv
# Shape: (3900, 5)
# Columns: ['epoch', 'step', 'gen_total', 'disc_loss', 'time_s']
#
# File: training_log 2.csv
# Shape: (3660, 5)
# Columns: ['epoch', 'step', 'gen_total', 'disc_loss', 'time_s']
#
# File: training_log 1.csv
# Shape: (3900, 5)
# Columns: ['epoch', 'step', 'gen_total', 'disc_loss', 'time_s']
#
# File: training_log 5.csv
# Shape: (3900, 5)
# Columns: ['epoch', 'step', 'gen_total', 'disc_loss', 'time_s']
#
# File: training_log 8.csv
# Shape: (234, 5)
# Columns: ['epoch', 'step', 'gen_total', 'disc_loss', 'time_s']

# %%
print(df.columns.tolist())
# Out:
# ['epoch', 'step', 'gen_total', 'disc_loss', 'time_s']

# %%
target_column = "SoH"

# %%
target_column = "RUL"

# %%
print(df.isnull().sum())
# Out:
# epoch        0
# step         0
# gen_total    0
# disc_loss    0
# time_s       0
# dtype: int64

# %%
feature_columns = [
    "cycle",
    "voltage",
    "current",
    "temperature",
    "capacity"
]

target_column = "SoH"

# %%
print("Actual columns in your dataset:")
print(df.columns.tolist())

print("\nFirst 5 rows:")
display(df.head())
# Out:
# Actual columns in your dataset:
# ['epoch', 'step', 'gen_total', 'disc_loss', 'time_s']
#
# First 5 rows:
#    epoch  step  gen_total  disc_loss     time_s
# 0     62     1   5.130928   0.749042  29.679657
# 1     62     2   5.337514   0.698042  34.161528
# 2     62     3   6.094767   0.698099  38.682715
# 3     62     4   5.333790   0.685004  43.190114
# 4     62     5  13.008395   0.712128  47.711985

# %%
print("Dataset columns:")
print(df.columns.tolist())

print("\nDataset shape:")
print(df.shape)

print("\nFirst 5 rows:")
display(df.head())
# Out:
# Dataset columns:
# ['epoch', 'step', 'gen_total', 'disc_loss', 'time_s']
#
# Dataset shape:
# (1521, 5)
#
# First 5 rows:
#    epoch  step  gen_total  disc_loss     time_s
# 0     62     1   5.130928   0.749042  29.679657
# 1     62     2   5.337514   0.698042  34.161528
# 2     62     3   6.094767   0.698099  38.682715
# 3     62     4   5.333790   0.685004  43.190114
# 4     62     5  13.008395   0.712128  47.711985

# %%
import numpy as np
import pandas as pd

# Sort data by epoch and step
df = df.sort_values(["epoch", "step"]).reset_index(drop=True)

# Features
feature_columns = [
    "epoch",
    "step",
    "disc_loss",
    "time_s"
]

# Target
target_column = "gen_total"

X = df[feature_columns].values
y = df[target_column].values

print("Features:", feature_columns)
print("Target:", target_column)
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# Features: ['epoch', 'step', 'disc_loss', 'time_s']
# Target: gen_total
# X shape: (1521, 4)
# y shape: (1521,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

print("Normalized data shape:", X_scaled.shape)
# Out:
# Normalized data shape: (1521, 4)

# %%
import numpy as np

SEQUENCE_LENGTH = 10

X_seq = []
y_seq = []

for i in range(len(X_scaled) - SEQUENCE_LENGTH):
    X_seq.append(X_scaled[i:i + SEQUENCE_LENGTH])
    y_seq.append(y[i + SEQUENCE_LENGTH])

X_seq = np.array(X_seq)
y_seq = np.array(y_seq)

print("Sequence X shape:", X_seq.shape)
print("Sequence y shape:", y_seq.shape)
# Out:
# Sequence X shape: (1511, 10, 4)
# Sequence y shape: (1511,)

# %%
n = len(X_seq)

train_end = int(0.70 * n)
val_end = int(0.85 * n)

X_train = X_seq[:train_end]
y_train = y_seq[:train_end]

X_val = X_seq[train_end:val_end]
y_val = y_seq[train_end:val_end]

X_test = X_seq[val_end:]
y_test = y_seq[val_end:]

print("Training:", X_train.shape)
print("Validation:", X_val.shape)
print("Testing:", X_test.shape)
# Out:
# Training: (1057, 10, 4)
# Validation: (227, 10, 4)
# Testing: (227, 10, 4)

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader

X_train_t = torch.tensor(X_train, dtype=torch.float32)
y_train_t = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)

X_val_t = torch.tensor(X_val, dtype=torch.float32)
y_val_t = torch.tensor(y_val, dtype=torch.float32).view(-1, 1)

X_test_t = torch.tensor(X_test, dtype=torch.float32)
y_test_t = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

print("Tensor conversion successful!")
print("Training tensor:", X_train_t.shape)
print("Validation tensor:", X_val_t.shape)
print("Testing tensor:", X_test_t.shape)
# Out:
# Tensor conversion successful!
# Training tensor: torch.Size([1057, 10, 4])
# Validation tensor: torch.Size([227, 10, 4])
# Testing tensor: torch.Size([227, 10, 4])

# %%
batch_size = 32

train_loader = DataLoader(
    TensorDataset(X_train_t, y_train_t),
    batch_size=batch_size,
    shuffle=True
)

val_loader = DataLoader(
    TensorDataset(X_val_t, y_val_t),
    batch_size=batch_size,
    shuffle=False
)

test_loader = DataLoader(
    TensorDataset(X_test_t, y_test_t),
    batch_size=batch_size,
    shuffle=False
)

print("DataLoaders created successfully!")
print("Training batches:", len(train_loader))
print("Validation batches:", len(val_loader))
print("Testing batches:", len(test_loader))
# Out:
# DataLoaders created successfully!
# Training batches: 34
# Validation batches: 8
# Testing batches: 8

# %%
import torch.nn as nn

input_size = X_train.shape[2]

class GRUModel(nn.Module):
    def __init__(self, input_size):
        super().__init__()

        self.gru = nn.GRU(
            input_size=input_size,
            hidden_size=64,
            num_layers=2,
            batch_first=True,
            dropout=0.2
        )

        self.fc = nn.Linear(64, 1)

    def forward(self, x):
        output, hidden = self.gru(x)

        last_output = output[:, -1, :]

        return self.fc(last_output)


model = GRUModel(input_size)

print(model)
# Out:
# GRUModel(
#   (gru): GRU(4, 64, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
total_params = sum(p.numel() for p in model.parameters())

trainable_params = sum(
    p.numel() for p in model.parameters()
    if p.requires_grad
)

print("Total parameters:", total_params)
print("Trainable parameters:", trainable_params)
# Out:
# Total parameters: 38465
# Trainable parameters: 38465

# %%
criterion = nn.MSELoss()

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=0.001
)

print("Loss function and optimizer are ready!")
# Out:
# Loss function and optimizer are ready!

# %%
import time
import copy

epochs = 30

train_losses = []
val_losses = []

best_val_loss = float("inf")
best_model = None

start_time = time.time()

for epoch in range(epochs):

    # -------------------------
    # Training
    # -------------------------
    model.train()

    total_train_loss = 0

    for X_batch, y_batch in train_loader:

        optimizer.zero_grad()

        predictions = model(X_batch)

        loss = criterion(predictions, y_batch)

        loss.backward()

        optimizer.step()

        total_train_loss += loss.item()

    train_loss = total_train_loss / len(train_loader)

    # -------------------------
    # Validation
    # -------------------------
    model.eval()

    total_val_loss = 0

    with torch.no_grad():

        for X_batch, y_batch in val_loader:

            predictions = model(X_batch)

            loss = criterion(predictions, y_batch)

            total_val_loss += loss.item()

    val_loss = total_val_loss / len(val_loader)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    # -------------------------
    # Save best model
    # -------------------------
    if val_loss < best_val_loss:

        best_val_loss = val_loss

        best_model = copy.deepcopy(model.state_dict())

        torch.save(
            best_model,
            "/content/best_gru_model.pth"
        )

    print(
        f"Epoch {epoch+1:02d}/{epochs} | "
        f"Train Loss: {train_loss:.6f} | "
        f"Validation Loss: {val_loss:.6f}"
    )

runtime = time.time() - start_time

print("\nTraining completed!")
print("Training runtime:", round(runtime, 2), "seconds")
print("Best validation loss:", best_val_loss)
# Out:
# Epoch 01/30 | Train Loss: 32.942853 | Validation Loss: 15.336035
# Epoch 02/30 | Train Loss: 11.485100 | Validation Loss: 11.116594
# Epoch 03/30 | Train Loss: 11.357516 | Validation Loss: 11.109030
# Epoch 04/30 | Train Loss: 11.412835 | Validation Loss: 11.106335
# Epoch 05/30 | Train Loss: 11.497523 | Validation Loss: 11.095267
# Epoch 06/30 | Train Loss: 11.310568 | Validation Loss: 11.083205
# Epoch 07/30 | Train Loss: 11.462529 | Validation Loss: 11.082508
# Epoch 08/30 | Train Loss: 11.333992 | Validation Loss: 11.100662
# Epoch 09/30 | Train Loss: 11.437144 | Validation Loss: 11.082039
# Epoch 10/30 | Train Loss: 11.320481 | Validation Loss: 11.103304
# Epoch 11/30 | Train Loss: 11.310611 | Validation Loss: 11.085593
# Epoch 12/30 | Train Loss: 11.338612 | Validation Loss: 11.080747
# Epoch 13/30 | Train Loss: 11.383645 | Validation Loss: 11.076844
# Epoch 14/30 | Train Loss: 14.648961 | Validation Loss: 11.077815
# ...

# %%
model.load_state_dict(
    torch.load(
        "/content/best_gru_model.pth",
        weights_only=True
    )
)

model.eval()

print("Best GRU model loaded successfully!")
# Out:
# Best GRU model loaded successfully!

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

plt.plot(train_losses, label="Training Loss")
plt.plot(val_losses, label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.title("GRU Training and Validation Loss")

plt.legend()
plt.grid(True)

plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

model.eval()

predictions = []
actual = []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        pred = model(X_batch)

        predictions.extend(pred.numpy().flatten())
        actual.extend(y_batch.numpy().flatten())

predictions = np.array(predictions)
actual = np.array(actual)

print("Predictions generated successfully!")
print("Number of test samples:", len(actual))
# Out:
# Predictions generated successfully!
# Number of test samples: 227

# %%
mae = mean_absolute_error(actual, predictions)

rmse = np.sqrt(
    mean_squared_error(actual, predictions)
)

mape = np.mean(
    np.abs((actual - predictions) /
           np.maximum(np.abs(actual), 1e-8))
) * 100

r2 = r2_score(actual, predictions)

print("\n===== GRU Evaluation Results =====")
print("MAE  :", round(mae, 6))
print("RMSE :", round(rmse, 6))
print("MAPE :", round(mape, 4), "%")
print("R²   :", round(r2, 6))
# Out:
# ===== GRU Evaluation Results =====
# MAE  : 2.397691
# RMSE : 3.15383
# MAPE : 39.1008 %
# R²   : -0.002748

# %%
plt.figure(figsize=(8, 5))

plt.plot(actual, label="Actual")
plt.plot(predictions, label="Predicted")

plt.xlabel("Test Sample")
plt.ylabel("gen_total")
plt.title("GRU: Actual vs Predicted gen_total")

plt.legend()
plt.grid(True)

plt.show()

# %%
results = pd.DataFrame({
    "Actual": actual,
    "Predicted": predictions
})

results.to_csv(
    "/content/gru_predictions.csv",
    index=False
)

metrics = pd.DataFrame({
    "Metric": [
        "MAE",
        "RMSE",
        "MAPE",
        "R2",
        "Runtime_seconds",
        "Parameters"
    ],
    "GRU": [
        mae,
        rmse,
        mape,
        r2,
        runtime,
        total_params
    ]
})

metrics.to_csv(
    "/content/gru_metrics.csv",
    index=False
)

print("GRU results saved successfully!")
# Out:
# GRU results saved successfully!

# %%
print("===== FINAL GRU RESULTS =====")
print("MAE :", round(mae, 6))
print("RMSE:", round(rmse, 6))
print("MAPE:", round(mape, 4), "%")
print("R²  :", round(r2, 6))
print("Runtime:", round(runtime, 2), "seconds")
print("Parameters:", total_params)
# Out:
# ===== FINAL GRU RESULTS =====
# MAE : 2.397691
# RMSE: 3.15383
# MAPE: 39.1008 %
# R²  : -0.002748
# Runtime: 12.35 seconds
# Parameters: 38465

# %%
lstm_mae = 0       # Replace with your actual LSTM MAE
lstm_rmse = 0      # Replace with your actual LSTM RMSE
lstm_mape = 0      # Replace with your actual LSTM MAPE
lstm_r2 = 0        # Replace with your actual LSTM R²
lstm_runtime = 0   # Replace with your actual LSTM runtime
lstm_params = 0    # Replace with your actual LSTM parameters

comparison = pd.DataFrame({
    "Metric": [
        "MAE",
        "RMSE",
        "MAPE",
        "R²",
        "Runtime (seconds)",
        "Parameters"
    ],
    "LSTM": [
        lstm_mae,
        lstm_rmse,
        lstm_mape,
        lstm_r2,
        lstm_runtime,
        lstm_params
    ],
    "GRU": [
        mae,
        rmse,
        mape,
        r2,
        runtime,
        total_params
    ]
})

display(comparison)
# Out:
#               Metric  LSTM           GRU
# 0                MAE     0      2.397691
# 1               RMSE     0      3.153830
# 2               MAPE     0     39.100750
# 3                 R²     0     -0.002748
# 4  Runtime (seconds)     0     12.350713
# 5         Parameters     0  38465.000000

# %% [markdown]
# ## Final Conclusion
#
# The GRU model was successfully implemented using sequential
# GAN training-log data.
#
# The model used a sequence length of 10 and four input features:
# epoch, step, disc_loss and time_s.
#
# The data was divided into training, validation and testing sets
# using a 70:15:15 split.
#
# Training and validation losses were monitored and the best GRU
# model was saved using a validation-loss checkpoint.
#
# The GRU model was evaluated using MAE, RMSE, MAPE and R².
# Training runtime and model parameter count were also recorded.
#
# The GRU results will be compared with the LSTM baseline using
# the same data split and evaluation metrics.
#
# Note: This experiment predicts GAN training-log behaviour
# (gen_total). It is not an SoH/RUL experiment because the
# available underwater dataset does not contain SoH or RUL labels.
